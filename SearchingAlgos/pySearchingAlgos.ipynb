# %% [markdown]
# > ### **Sorting Algorithms**
#
# > *Created by Jason Naicker*.
#
# > *[Github](https://github.com/JasonNaicker)*
#
# ---

# %%
def SelectionSearch():
    pass

# %%
def BinarySearch():
    pass

# %%
def QuickSelect():
    pass

# %%
def MedianOfMedians():
    pass
